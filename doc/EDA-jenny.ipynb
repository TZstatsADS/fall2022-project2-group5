# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %% [markdown]
# ## Covid-19 Daily Counts of Cases, Hospitalizations and Deaths

# %%
df_covid = pd.read_csv('COVID-19_Daily_Counts_of_Cases__Hospitalizations__and_Deaths.csv')

# %%
df_covid
# Out:
#     date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  \
# 0         02/29/2020           1                    0                   1
# 1         03/01/2020           0                    0                   1
# 2         03/02/2020           0                    0                   2
# 3         03/03/2020           1                    0                   7
# 4         03/04/2020           5                    0                   2
# ..               ...         ...                  ...                 ...
# 942       09/28/2022        1999                  505                  81
# 943       09/29/2022        1770                  470                  47
# 944       09/30/2022        1495                  395                  15
# 945       10/01/2022         821                  271                   5
# 946       10/02/2022         788                  371                   7
#
#      DEATH_COUNT  PROBABLE_DEATH_COUNT  CASE_COUNT_7DAY_AVG  \
# ...

# %%
len(df_covid.columns)
# Out:
# 67

# %%
df_covid.columns
# Out:
# Index(['date_of_interest', 'CASE_COUNT', 'PROBABLE_CASE_COUNT',
#        'HOSPITALIZED_COUNT', 'DEATH_COUNT', 'PROBABLE_DEATH_COUNT',
#        'CASE_COUNT_7DAY_AVG', 'ALL_CASE_COUNT_7DAY_AVG', 'HOSP_COUNT_7DAY_AVG',
#        'DEATH_COUNT_7DAY_AVG', 'ALL_DEATH_COUNT_7DAY_AVG', 'BX_CASE_COUNT',
#        'BX_PROBABLE_CASE_COUNT', 'BX_HOSPITALIZED_COUNT', 'BX_DEATH_COUNT',
#        'BX_PROBABLE_DEATH_COUNT', 'BX_CASE_COUNT_7DAY_AVG',
#        'BX_PROBABLE_CASE_COUNT_7DAY_AVG', 'BX_ALL_CASE_COUNT_7DAY_AVG',
#        'BX_HOSPITALIZED_COUNT_7DAY_AVG', 'BX_DEATH_COUNT_7DAY_AVG',
#        'BX_ALL_DEATH_COUNT_7DAY_AVG', 'BK_CASE_COUNT',
#        'BK_PROBABLE_CASE_COUNT', 'BK_HOSPITALIZED_COUNT', 'BK_DEATH_COUNT',
#        'BK_PROBABLE_DEATH_COUNT', 'BK_CASE_COUNT_7DAY_AVG',
#        'BK_PROBABLE_CASE_COUNT_7DAY_AVG', 'BK_ALL_CASE_COUNT_7DAY_AVG',
#        'BK_HOSPITALIZED_COUNT_7DAY_AVG', 'BK_DEATH_COUNT_7DAY_AVG',
#        'BK_ALL_DEATH_COUNT_7DAY_AVG', 'MN_CASE_COUNT',
# ...

# %% [markdown]
# ### features
# - Date_of_interest:
# Date of COVID-19 diagnosis (i.e., date of specimen collection), hospital admission, or death.
# - Case_count:
# Count of patients tested who were confirmed to be COVID-19 cases on date_of _interest
# - Hospitalized_count:
# Count of COVID-19 patients who were hospitalized on date_of_interest
# - Death_count:
# Count of deaths occurring among confirmed COVID-19 cases on date_of_interest.
# - Death_count_probable:
# Count of probable deaths occurring on date_of_interest. Probable deaths include those with cause of death reported as "COVID-19" or equivalent, but there is no positive laboratory test for COVID-19.
# - Case_count_7day_avg:
# 7-day average of count of patients tested who were confirmed to be COVID-19 cases. The seven days include the current day and the previous six days.
# - Hosp_count_7day_avg:
# 7-day average of count of COVID-19 patients who were hospitalized. The seven days include the current day and the previous six days.
# - Death_count_7day_avg:
# 7-day average of count of deaths occurring among confirmed COVID-19 cases. The seven days include the current day and the previous six days.
# - Bx_case_count:
# Count of patients tested who were confirmed to be COVID-19 cases on date_of _interest in the Bronx.
# - Bx_hospitalized_count:
# Count of COVID-19 patients who were hospitalized on date_of_interest in the Bronx.
# - Bx_death_count:
# Count of deaths occurring among confirmed COVID-19 cases on date_of_interest in the Bronx.
# - Bx_case_count_7day_avg:
# 7-day average of count of patients tested who were confirmed to be COVID-19 cases in the Bronx. The seven days include the current day and the previous six days.
# - Bx_hospitalized_count_7day_avg:
# 7-day average of count of COVID-19 patients who were hospitalized in the Bronx. The seven days include the current day and the previous six days.
#
# - Bx_death_count_7day_avg: 7-day average of count of deaths occurring among confirmed COVID-19 cases in the Bronx. The seven days include the current day and the previous six days.
#
# - Bk_case_count: Count of patients tested who were confirmed to be COVID-19 cases on date_of _interest in Brooklyn.
#
# - Bk_hospitalized_count: Count of COVID-19 patients who were hospitalized on date_of_interest in Brooklyn.
#
# - Bk_death_count: Count of deaths occurring among confirmed COVID-19 cases on date_of_interest in Brooklyn.
#
# - Bk_case_count_7day_avg: 7-day average of count of patients tested who were confirmed to be COVID-19 cases in Brooklyn. The seven days include the current day and the previous six days.
#
# - Bk_hospitalized_count_7day_avg: 7-day average of count of COVID-19 patients who were hospitalized in Brooklyn. The seven days include the current day and the previous six days.
#
# - Bk_death_count_7day_avg: 7-day average of count of deaths occurring among confirmed COVID-19 cases in Brooklyn. The seven days include the current day and the previous  six days.
#
# - Mn_case_count: Count of patients tested who were confirmed to be COVID-19 cases on date_of _interest in Manhattan.
#
# - Mn_hospitalized_count: Count of COVID-19 patients who were hospitalized on date_of_interest in Manhattan.
#
# - Mn_death_count: Count of deaths occurring among confirmed COVID-19 cases on date_of_interest in Manhattan.
#
# - Mn_case_count_7day_avg: 7-day average of count of patients tested who were confirmed to be COVID-19 cases in Manhattan. The seven days include the current day and the previous six days.
#
# - Mn_hospitalized_count_7day_avg: 7-day average of count of COVID-19 patients who were hospitalized in Manhattan. The seven days include the current day and the previous six days.
#
# - Mn_death_count_7day_avg: 7-day average of count of deaths occurring among confirmed COVID-19 cases in Manhattan. The seven days include the current day and the previous six days.
#
# - Qn_case_count: Count of patients tested who were confirmed to be COVID-19 cases on date_of _interest in Queens.
#
# - Qn_hospitalized_count: Count of COVID-19 patients who were hospitalized on date_of_interest in Queens.
#
# - Qn_death_count: Count of deaths occurring among confirmed COVID-19 cases on date_of_interest in Queens.
#
# - Qn_case_count_7day_avg: 7-day average of count of patients tested who were confirmed to be COVID-19 cases in Queens. The seven days include the current day and the previous six days.
#
# - Qn_hospitalized_count_7day_avg: 7-day average of count of COVID-19 patients who were hospitalized in Queens. The seven days include the current day and the previous six days.
#
# - Qn_death_count_7day_avg: 7-day average of count of deaths occurring among confirmed COVID-19 cases in Queens. The seven days include the current day and the previous six days.
#
# - Si_case_count: Count of patients tested who were confirmed to be COVID-19 cases on date_of _interest in Staten Island.
#
# - Si_hospitalized_count: Count of COVID-19 patients who were hospitalized on date_of_interest in Staten Island.
#
# - Si_death_count: Count of deaths occurring among confirmed COVID-19 cases on date_of_interest in Staten Island.
#
# - Si_case_count_7day_avg: 7-day average of count of patients tested who were confirmed to be COVID-19 cases in Staten Island. The seven days include the current day and the previous six days.
#
# - Si_hospitalized_count_7day_avg: 7-day average of count of COVID-19 patients who were hospitalized in Staten Island. The seven days include the current day and the previous six days.
#
# - Si_death_count_7day_avg: 7-day average of count of deaths occurring among confirmed COVID-19 cases in Staten Island. The seven days include the current day and the previous six days.
#
# - Incomplete: Used for display purposes only.

# %%
df_covid.describe()
# Out:
#          CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT  \
# count    947.000000           947.000000          947.000000   947.000000
# mean    2568.068638           476.477297          176.965153    38.348469
# std     5359.761866           666.952799          263.366094    81.351786
# min        0.000000             0.000000            1.000000     0.000000
# 25%      541.500000            69.500000           44.000000     6.000000
# 50%     1387.000000           322.000000           87.000000    12.000000
# 75%     2882.000000           646.500000          193.000000    38.000000
# max    54931.000000          5881.000000         1847.000000   598.000000
#
#        PROBABLE_DEATH_COUNT  CASE_COUNT_7DAY_AVG  ALL_CASE_COUNT_7DAY_AVG  \
# count            947.000000           947.000000               947.000000
# mean               5.955649          2564.136220              3039.407603
# std               24.553349          4925.201653              5509.943523
# ...

# %% [markdown]
# ### unique `date_of_interest`
# no duplicates.

# %%
df_covid.date_of_interest.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### missing data
# no missing data.

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Data columns (total 67 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_of_interest                 947 non-null    object
#  1   CASE_COUNT                       947 non-null    int64
#  2   PROBABLE_CASE_COUNT              947 non-null    int64
#  3   HOSPITALIZED_COUNT               947 non-null    int64
#  4   DEATH_COUNT                      947 non-null    int64
#  5   PROBABLE_DEATH_COUNT             947 non-null    int64
#  6   CASE_COUNT_7DAY_AVG              947 non-null    int64
#  7   ALL_CASE_COUNT_7DAY_AVG          947 non-null    int64
#  8   HOSP_COUNT_7DAY_AVG              947 non-null    int64
#  9   DEATH_COUNT_7DAY_AVG             947 non-null    int64
#  10  ALL_DEATH_COUNT_7DAY_AVG         947 non-null    int64
#  11  BX_CASE_COUNT                    947 non-null    int64
# ...

# %% [markdown]
# ### skewness

# %% [markdown]
# none of the features are not skew, but we tend to do nothing about it.

# %%
fig,ax = plt.subplots(1, 3, figsize=(16,4))

sns.histplot(x=df_covid.CASE_COUNT, ax=ax[0])
ax[0].set_xlabel('Case Count')

sns.histplot(x=df_covid.PROBABLE_CASE_COUNT, ax=ax[1])
ax[1].set_xlabel('Probable Case Count')

sns.histplot(x=df_covid.HOSPITALIZED_COUNT, ax=ax[2])
ax[2].set_xlabel('Hospitalized Count');
## .apply(np.sqrt)
## .apply(np.log)

# %%
fig,ax = plt.subplots(1, 3, figsize=(16,4))

sns.histplot(x=df_covid.DEATH_COUNT, ax=ax[0])
ax[0].set_xlabel('Death Count')

sns.histplot(x=df_covid.PROBABLE_DEATH_COUNT, ax=ax[1])
ax[1].set_xlabel('Probable Death Count')

sns.histplot(x=df_covid.CASE_COUNT_7DAY_AVG, ax=ax[2])
ax[2].set_xlabel('Case Count 7day Avg');

# %%
fig,ax = plt.subplots(1, 4, figsize=(16,4))

sns.histplot(x=df_covid.ALL_CASE_COUNT_7DAY_AVG, ax=ax[0])
ax[0].set_xlabel('All Case Count 7day Avg')

sns.histplot(x=df_covid.DEATH_COUNT_7DAY_AVG, ax=ax[1])
ax[1].set_xlabel('Death Count 7day Avg')

sns.histplot(x=df_covid.DEATH_COUNT_7DAY_AVG, ax=ax[2])
ax[2].set_xlabel('Death Count 7day Avg'); 

sns.histplot(x=df_covid.ALL_DEATH_COUNT_7DAY_AVG, ax=ax[3])
ax[3].set_xlabel('All Death Count 7day Avg');

# %% [markdown]
# ### outliers
# same with the outliers

# %%
fig,ax = plt.subplots(1, 3, figsize=(16,4))

sns.boxplot(x=df_covid.CASE_COUNT, ax=ax[0])
ax[0].set_xlabel('Case Count')

sns.boxplot(x=df_covid.PROBABLE_CASE_COUNT, ax=ax[1])
ax[1].set_xlabel('Probable Case Count')

sns.boxplot(x=df_covid.HOSPITALIZED_COUNT, ax=ax[2])
ax[2].set_xlabel('Hospitalized Count');

# %% [markdown]
# ### group by month and borough
# 2020-03 to 2022-09

# %%
df_covid
# Out:
#     date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  \
# 0         02/29/2020           1                    0                   1
# 1         03/01/2020           0                    0                   1
# 2         03/02/2020           0                    0                   2
# 3         03/03/2020           1                    0                   7
# 4         03/04/2020           5                    0                   2
# ..               ...         ...                  ...                 ...
# 942       09/28/2022        1999                  505                  81
# 943       09/29/2022        1770                  470                  47
# 944       09/30/2022        1495                  395                  15
# 945       10/01/2022         821                  271                   5
# 946       10/02/2022         788                  371                   7
#
#      DEATH_COUNT  PROBABLE_DEATH_COUNT  CASE_COUNT_7DAY_AVG  \
# ...

# %%
covid = df_covid[['date_of_interest', 'CASE_COUNT', 'BX_CASE_COUNT', 'BK_CASE_COUNT', 
                  'MN_CASE_COUNT', 'QN_CASE_COUNT', 'SI_CASE_COUNT']]
covid
# Out:
#     date_of_interest  CASE_COUNT  BX_CASE_COUNT  BK_CASE_COUNT  MN_CASE_COUNT  \
# 0         02/29/2020           1              0              0              1
# 1         03/01/2020           0              0              0              0
# 2         03/02/2020           0              0              0              0
# 3         03/03/2020           1              0              0              0
# 4         03/04/2020           5              0              1              2
# ..               ...         ...            ...            ...            ...
# 942       09/28/2022        1999            326            560            414
# 943       09/29/2022        1770            231            544            356
# 944       09/30/2022        1495            234            405            307
# 945       10/01/2022         821             99            205            167
# 946       10/02/2022         788            106            203            162
#
# ...

# %%
covid['Date'] = pd.to_datetime(covid['date_of_interest'], format="%m/%d/%Y")

# %%
covid['month'] = [x.month for x in covid['Date']]

# %%
covid['year'] = [x.year for x in covid['Date']]

# %%
covid = covid[['year', 'month', 'CASE_COUNT', 'BX_CASE_COUNT', 'BK_CASE_COUNT',
               'MN_CASE_COUNT', 'QN_CASE_COUNT', 'SI_CASE_COUNT']]

# %%
covid.columns = ['year', 'month', 'CASE_COUNT', 'BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']

# %%
group = covid.groupby(['year', 'month'])
covid = group.sum()
covid
# Out:
#             CASE_COUNT  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# year month
# 2020 2               1      0         0          1       0              0
#      3           65182  12681     18516       9538   19983           4461
#      4          109297  26882     28742      11741   34120           7808
#      5           28416   6494      8654       3795    8184           1289
#      6           10844   2248      3111       1733    3219            533
#      7            9787   2018      2706       1921    2496            646
#      8            7446   1624      2262       1282    1852            426
#      9           11095   1536      4450       1762    2607            737
#      10          16924   2552      6126       2599    4322           1318
#      11          44762   7671     12276       7692   11810           5312
#      12          97787  16820     28781      13615   28469          10096
# ...

# %%
covid.to_csv('covid.csv')

# %% [markdown]
# ## Evictions

# %%
df_evictions = pd.read_csv('Evictions.csv')

# %%
df_evictions
# Out:
#       Court Index Number  Docket Number         Eviction Address  \
# 0              B67328/18           94978  835 EAST 152ND STREE T
# 1               79864/16            4676   2732 FULTON ST. BSMT.
# 2               48269/16           57672     2730 DECATUR AVENUE
# 3               36145/16          324855   624 EAST 222ND STREET
# 4               73977/19           28733      1166 EAST 105TH ST
# ...                  ...             ...                     ...
# 69936         K310254/21          104198          992 4TH AVENUE
# 69937           98284/17           80958       1327 EAST 88TH ST
# 69938            3878/19          354537       3250 THIRD AVENUE
# 69939            3878/19          354537       3250 THIRD AVENUE
# 69940           65139/19           99513       651 WEST 171ST ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            24    03/28/2019             Ileana
# ...

# %%
df_evictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69941 entries, 0 to 69940
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Court Index Number         69941 non-null  object
#  1   Docket Number              69941 non-null  int64
#  2   Eviction Address           69941 non-null  object
#  3   Eviction Apartment Number  58196 non-null  object
#  4   Executed Date              69941 non-null  object
#  5   Marshal First Name         69941 non-null  object
#  6   Marshal Last Name          69941 non-null  object
#  7   Residential/Commercial     69941 non-null  object
#  8   BOROUGH                    69941 non-null  object
#  9   Eviction Postcode          69941 non-null  int64
#  10  Ejectment                  69941 non-null  object
#  11  Eviction/Legal Possession  69941 non-null  object
#  12  Latitude                   63211 non-null  float64
# ...

# %% [markdown]
# ### missing data

# %%
69941 - len(df_evictions[(df_evictions.Latitude.isna()) & (df_evictions.Longitude.isna())])
# Out:
# 63211

# %% [markdown]
# - `Latitude` and `Longitude` are nan at the same time.
# - Every entry has `Eviction Address`, so there's no need to drop the nan entries.

# %% [markdown]
# ### duplicates

# %%
df_evictions[df_evictions['Docket Number '].duplicated()]
# Out:
#       Court Index Number  Docket Number                  Eviction Address  \
# 171             83263/19           27886            1446 EAST 98TH STREET
# 404             64657/19          356535             162 WEST 56TH STREET
# 480             67582/16          329944               1807 ARCHER STREET
# 874             67563/19           27879            229 BEACH 20TH STREET
# 1007           K60670/18          106069             213 SOUTH 3RD STREET
# ...                  ...             ...                              ...
# 69921           66707/17           13248        60A BAINBRIDGE ST - APT 1
# 69924           53619/17            7863  46 TOMPKINS STREET ENITRE HOUSE
# 69935         N077678/17          388094                  25 DONGAN PLACE
# 69939            3878/19          354537                3250 THIRD AVENUE
# 69940           65139/19           99513                651 WEST 171ST ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# ...

# %%
df_evictions[df_evictions['Docket Number '] == 27886]
# Out:
#      Court Index Number  Docket Number        Eviction Address  \
# 170            83263/19           27886  1446 EAST 98TH STREET
# 171            83263/19           27886  1446 EAST 98TH STREET
# 3283         54334/19-1           27886  1771 LINDEN BOULEVARD
#
#      Eviction Apartment Number Executed Date Marshal First Name  \
# 170                          1    02/03/2022             Edward
# 171                          1    02/03/2022             Edward
# 3283                       NaN    06/26/2019               Gary
#
#      Marshal Last Name Residential/Commercial   BOROUGH  Eviction Postcode  \
# 170              Guida            Residential  BROOKLYN              11236
# 171              Guida            Residential  BROOKLYN              11236
# 3283              Rose            Residential  BROOKLYN              11207
#
#              Ejectment Eviction/Legal Possession  Latitude  Longitude  \
# 170   Not an Ejectment                Possession   40.6380 -73.892869
# ...

# %%
df_evictions.drop_duplicates(subset=None,keep='first',inplace=True)

# %%
df_evictions
# Out:
#       Court Index Number  Docket Number         Eviction Address  \
# 0              B67328/18           94978  835 EAST 152ND STREE T
# 1               79864/16            4676   2732 FULTON ST. BSMT.
# 2               48269/16           57672     2730 DECATUR AVENUE
# 3               36145/16          324855   624 EAST 222ND STREET
# 4               73977/19           28733      1166 EAST 105TH ST
# ...                  ...             ...                     ...
# 69935         N077678/17          388094         25 DONGAN PLACE
# 69936         K310254/21          104198          992 4TH AVENUE
# 69937           98284/17           80958       1327 EAST 88TH ST
# 69938            3878/19          354537       3250 THIRD AVENUE
# 69940           65139/19           99513       651 WEST 171ST ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            24    03/28/2019             Ileana
# ...

# %% [markdown]
# ### sort

# %%
type(df_evictions['Executed Date'][1])
# Out:
# str

# %%
df_evictions['Executed Date'] = pd.to_datetime(df_evictions['Executed Date'], format="%m/%d/%Y")
df_evictions
# Out:
#       Court Index Number  Docket Number         Eviction Address  \
# 0              B67328/18           94978  835 EAST 152ND STREE T
# 1               79864/16            4676   2732 FULTON ST. BSMT.
# 2               48269/16           57672     2730 DECATUR AVENUE
# 3               36145/16          324855   624 EAST 222ND STREET
# 4               73977/19           28733      1166 EAST 105TH ST
# ...                  ...             ...                     ...
# 69935         N077678/17          388094         25 DONGAN PLACE
# 69936         K310254/21          104198          992 4TH AVENUE
# 69937           98284/17           80958       1327 EAST 88TH ST
# 69938            3878/19          354537       3250 THIRD AVENUE
# 69940           65139/19           99513       651 WEST 171ST ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            24    2019-03-28             Ileana
# ...

# %%
df_evictions = df_evictions.sort_values(by='Executed Date')

# %%
df_evictions
# Out:
#       Court Index Number  Docket Number   \
# 66286         K091781/16          374126
# 68793           49558/16           56540
# 42874           81583/16          329339
# 60614         N251948/16          374147
# 65926           75948/15          455184
# ...                  ...             ...
# 63752          307465/20          361270
# 31830           77883/17           15485
# 3866             9702/20          361275
# 64162          303146/22          361217
# 66669          300909/21           28125
#
#                                         Eviction Address  \
# 66286                              253 CUMBERLAND STREET
# 68793                                   1744 CLAY AVENUE
# 42874                                   220 SOUTH STREET
# 60614                                   620 LENOX AVENUE
# 65926                             935 EAST 178TH STREE T
# ...                                                  ...
# 63752                                    3030 ELY AVENUE
# ...

# %%
df_evictions.BOROUGH.value_counts()
# Out:
# BRONX            22692
# BROOKLYN         20133
# QUEENS           13804
# MANHATTAN        10748
# STATEN ISLAND     2377
# Name: BOROUGH, dtype: int64

# %% [markdown]
# ### group by date and zip code

# %%
df = pd.DataFrame(df_evictions.groupby(by=['Executed Date', 'Eviction Postcode']).size(),
                  columns=['Number of Evictions'])

# %%
df
# Out:
#                                  Number of Evictions
# Executed Date Eviction Postcode
# 2017-01-03    10002                                2
#               10003                                1
#               10017                                1
#               10018                                1
#               10019                                1
# ...                                              ...
# 2022-10-05    10306                                1
#               10460                                1
#               10469                                1
#               10474                                1
#               11434                                1
#
# [40770 rows x 1 columns]

# %%
df['Number of Evictions'].describe()
# Out:
# count    40770.000000
# mean         1.710915
# std          1.160762
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         18.000000
# Name: Number of Evictions, dtype: float64

# %%
fig,ax = plt.subplots()

sns.histplot(x=df['Number of Evictions']);

# %% [markdown]
# ### group by week

# %%
df_evictions
# Out:
#       Court Index Number  Docket Number   \
# 66286         K091781/16          374126
# 68793           49558/16           56540
# 42874           81583/16          329339
# 60614         N251948/16          374147
# 65926           75948/15          455184
# ...                  ...             ...
# 63752          307465/20          361270
# 31830           77883/17           15485
# 3866             9702/20          361275
# 64162          303146/22          361217
# 66669          300909/21           28125
#
#                                         Eviction Address  \
# 66286                              253 CUMBERLAND STREET
# 68793                                   1744 CLAY AVENUE
# 42874                                   220 SOUTH STREET
# 60614                                   620 LENOX AVENUE
# 65926                             935 EAST 178TH STREE T
# ...                                                  ...
# 63752                                    3030 ELY AVENUE
# ...

# %%
df_evictions['weekday'] = [x.weekday() for x in df_evictions['Executed Date']]

# %%
df_evictions
# Out:
#       Court Index Number  Docket Number   \
# 66286         K091781/16          374126
# 68793           49558/16           56540
# 42874           81583/16          329339
# 60614         N251948/16          374147
# 65926           75948/15          455184
# ...                  ...             ...
# 63752          307465/20          361270
# 31830           77883/17           15485
# 3866             9702/20          361275
# 64162          303146/22          361217
# 66669          300909/21           28125
#
#                                         Eviction Address  \
# 66286                              253 CUMBERLAND STREET
# 68793                                   1744 CLAY AVENUE
# 42874                                   220 SOUTH STREET
# 60614                                   620 LENOX AVENUE
# 65926                             935 EAST 178TH STREE T
# ...                                                  ...
# 63752                                    3030 ELY AVENUE
# ...

# %%
df_week = pd.DataFrame(df_evictions.groupby([pd.Grouper(key='Executed Date', freq='W'), 'Eviction Postcode']).size(),
                       columns=['Number of Evictions'])

# %%
df_week
# Out:
#                                  Number of Evictions
# Executed Date Eviction Postcode
# 2017-01-08    10001                                4
#               10002                                6
#               10003                                4
#               10009                                1
#               10010                                1
# ...                                              ...
# 2022-10-09    11230                                1
#               11235                                2
#               11236                                1
#               11365                                1
#               11434                                1
#
# [21605 rows x 1 columns]

# %%
df_week.describe()
# Out:
#                   0
# count  21605.000000
# mean       3.228604
# std        3.057947
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       29.000000

# %%
fig,ax = plt.subplots()

sns.histplot(x=df_week['Number of Evictions']);

# %% [markdown]
# ### group by months and borough
# 2017-02 to 2022-09

# %%
eviction = pd.DataFrame(df_evictions.groupby([pd.Grouper(key='Executed Date', freq='M'), 'BOROUGH']).size(),
                       columns=['Number of Evictions'])

# %%
eviction.reset_index(inplace=True)

# %%
eviction = eviction.pivot(index='Executed Date', columns='BOROUGH', values='Number of Evictions')

# %%
eviction.reset_index(inplace=True)

# %%
eviction['year'] = [x.year for x in eviction['Executed Date']]

# %%
eviction['month'] = [x.month for x in eviction['Executed Date']]

# %%
eviction = eviction.rename_axis(None, axis=1)

# %%
eviction = eviction[['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND', 'year', 'month']].set_index(['year', 'month'])

# %%
eviction
# Out:
#             BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# year month
# 2017 1      765.0     637.0      346.0   419.0           68.0
#      2      543.0     509.0      258.0   317.0           64.0
#      3      657.0     599.0      291.0   430.0           62.0
#      4      603.0     537.0      306.0   347.0           65.0
#      5      736.0     557.0      308.0   401.0           78.0
# ...           ...       ...        ...     ...            ...
# 2022 6       83.0     158.0       65.0    81.0           19.0
#      7       82.0     158.0       76.0    69.0           22.0
#      8       86.0     225.0       90.0    79.0           16.0
#      9      133.0     178.0      107.0    98.0           16.0
#      10      14.0      12.0       14.0     3.0            3.0
#
# [63 rows x 5 columns]

# %%
eviction.to_csv('eviction.csv')
